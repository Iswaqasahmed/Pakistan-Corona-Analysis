# %%
import numpy as np
import pandas as pd

# %%
pkCovid = pd.read_csv("C:\\Users\\shariq\\OneDrive\\Data Analysis Git\\Pakistan Corona Analysis\\pakistan corona dataset\\PK COVID-19.csv",nrows=847)

# %%
pkCovid.head(10)
# Out:
#         Date  Cases  Deaths  Recovered Travel_history  \
# 0  2/26/2020      1       0          0          China
# 1  2/26/2020      2       0          0    Iran/Taftan
# 2  2/29/2020      1       0          0          China
# 3  2/29/2020      1       0          0    Iran/Taftan
# 4   3/2/2020      1       0          0    Iran/Taftan
# 5   3/6/2020      0       0          1        Unknown
# 6   3/7/2020      1       0          0    Iran/Taftan
# 7   3/9/2020      6       0          0          Syria
# 8   3/9/2020      3       0          0             UK
# 9  3/10/2020      1       0          0    Iran/Taftan
#
#                       Province       City
# 0  Islamabad Capital Territory  Islamabad
# 1                        Sindh    Karachi
# 2  Islamabad Capital Territory  Islamabad
# 3                        Sindh    Karachi
# 4             Gilgit-Baltistan     Gilgit
# 5                        Sindh    Karachi
# 6                        Sindh    Karachi
# ...

# %%
pkCovid.tail(10)
# Out:
#           Date  Cases  Deaths  Recovered          Travel_history Province  \
# 837  4/19/2020      1       0          0  Local - Social Contact   Punjab
# 838  4/19/2020     23       0          0  Local - Social Contact   Punjab
# 839  4/19/2020      0       0          1  Local - Social Contact   Punjab
# 840  4/19/2020      7       0          0  Local - Social Contact   Punjab
# 841  4/19/2020      0       0          4  Local - Social Contact   Punjab
# 842  4/19/2020     76       0          0  Local - Social Contact   Punjab
# 843  4/19/2020      5       0          0  Local - Social Contact   Punjab
# 844  4/19/2020      5       0          0  Local - Social Contact   Punjab
# 845  4/19/2020      3       0          0  Local - Social Contact   Punjab
# 846  4/19/2020      1       0          0  Local - Social Contact   Punjab
#
#                City
# 837         Sahewal
# 838         Sialkot
# 839       Hafizabad
# 840         Nankana
# 841      Bahawalpur
# 842         Lodhran
# ...

# %%
pkCovid.Travel_history.unique()
# Out:
# array(['China', 'Iran/Taftan', 'Unknown', 'Syria', 'UK',
#        'Local - Social Contact', 'USA', 'KSA', 'Local - Covid Relative',
#        'International Passenger', 'Dubai', 'Tableeghi Jamaat',
#        'Tableegi Jamaat', 'Jail', 'India'], dtype=object)

# %%
pkCovid["Travel_history"] = pkCovid['Travel_history'].replace("[ ].*","",regex=True)

# %%
pkCovid["Travel_history"] = pkCovid['Travel_history'].replace("Unknown","Local",regex=True)

# %%
pkCovid["Travel_history"] = pkCovid['Travel_history'].replace(["Tableeghi",'Tableegi','Jail'],"Local",regex=True)

# %%
pkCovid.head()
# Out:
#         Date  Cases  Deaths  Recovered Travel_history  \
# 0  2/26/2020      1       0          0          China
# 1  2/26/2020      2       0          0    Iran/Taftan
# 2  2/29/2020      1       0          0          China
# 3  2/29/2020      1       0          0    Iran/Taftan
# 4   3/2/2020      1       0          0    Iran/Taftan
#
#                       Province       City
# 0  Islamabad Capital Territory  Islamabad
# 1                        Sindh    Karachi
# 2  Islamabad Capital Territory  Islamabad
# 3                        Sindh    Karachi
# 4             Gilgit-Baltistan     Gilgit

# %%
pkCovid.Travel_history.unique()
# Out:
# array(['China', 'Iran/Taftan', 'Unknown', 'Syria', 'UK',
#        'Local - Social Contact', 'USA', 'KSA', 'Local - Covid Relative',
#        'International Passenger', 'Dubai', 'Tableeghi Jamaat',
#        'Tableegi Jamaat', 'Jail', 'India'], dtype=object)

# %%
pkCovid['Province'].unique()
# Out:
# array(['Islamabad Capital Territory', 'Sindh', 'Gilgit-Baltistan',
#        'Baluchistan', 'Punjab', 'Khyber Pakhtunkhwa',
#        'khyber Pakhtunkhwa', 'Azad Jummu Kashmir',
#        'Federal Administration Tribal Area'], dtype=object)

# %%
pkCovid[pkCovid['Province'] == 'Khyber Pakhtunkhwa'].head()
# Out:
#          Date  Cases  Deaths  Recovered          Travel_history  \
# 21  3/15/2020     15       0          0             Iran/Taftan
# 22  3/15/2020      1       1          0                 Unknown
# 29  3/16/2020      1       0          0                 Unknown
# 35  3/17/2020      1       0          0                      UK
# 43  3/18/2020      1       0          0  Local - Social Contact
#
#               Province              City
# 21  Khyber Pakhtunkhwa  Dera Ismail Khan
# 22  Khyber Pakhtunkhwa            Mardan
# 29  Khyber Pakhtunkhwa            Mardan
# 35  Khyber Pakhtunkhwa         Charsadda
# 43  Khyber Pakhtunkhwa             Buner

# %%
pkCovid['Province'] = pkCovid['Province'].replace('khyber Pakhtunkhwa','Khyber Pakhtunkhwa',regex=True)

# %%
pkCovid['Province'].unique()
# Out:
# array(['Islamabad Capital Territory', 'Sindh', 'Gilgit-Baltistan',
#        'Baluchistan', 'Punjab', 'Khyber Pakhtunkhwa',
#        'Azad Jummu Kashmir', 'Federal Administration Tribal Area'],
#       dtype=object)

# %%
pkCovid['Date'].unique()
# Out:
# array(['2/26/2020', '2/29/2020', '3/2/2020', '3/6/2020', '3/7/2020',
#        '3/9/2020', '3/10/2020', '3/11/2020', '3/12/2020', '3/13/2020',
#        '3/15/2020', '3/16/2020', '3/17/2020', '3/18/2020', '3/19/2020',
#        '3/20/2020', '3/21/2020', '3/22/2020', '3/23/2020', '3/24/2020',
#        '3/25/2020', '3/26/2020', '3/27/2020', '3/28/2020', '3/29/2020',
#        '3/30/2020', '3/31/2020', '4/1/2020', '4/2/2020', '4/3/2020',
#        '4/4/2020', '4/5/2020', '4/6/2020', '4/7/2020', '4/8/2020',
#        '4/9/2020', '4/10/2020', '4/11/2020', '4/12/2020', '4/13/2020',
#        '4/14/2020', '4/15/2020', '4/16/2020', '4/17/2020', '4/18/2020',
#        '4/19/2020'], dtype=object)

# %%
pkCovid.isna().sum()
# Out:
# Date                0
# Cases               0
# Deaths              0
# Recovered           0
# Travel_history    847
# Province            0
# City                0
# dtype: int64

# %%
pkCovid[['Deaths','Recovered','Province']].groupby(['Province']).mean()
# Out:
#                                       Deaths  Recovered
# Province
# Azad Jummu Kashmir                  0.000000   0.055556
# Baluchistan                         0.138889   4.638889
# Federal Administration Tribal Area  0.000000   0.343750
# Gilgit-Baltistan                    0.051724   3.362069
# Islamabad Capital Territory         0.068966   0.517241
# Khyber Pakhtunkhwa                  0.240157   0.771654
# Punjab                              0.137584   2.298658
# Sindh                               0.466667   7.208333
# khyber Pakhtunkhwa                  0.000000   0.000000

# %%
pkCovid[['Deaths','Recovered',"City",'Province']].groupby(['Province','City']).mean()
# Out:
#                                                           Deaths  Recovered
# Province                           City
# Azad Jummu Kashmir                 Bhambore             0.000000   0.000000
#                                    Mirpur               0.000000   0.000000
#                                    Muzaffarabad         0.000000   0.076923
#                                    Trarkhel             0.000000   0.000000
# Baluchistan                        Quetta               0.147059   4.911765
#                                    Taftan               0.000000   0.000000
# Federal Administration Tribal Area Bajaur               0.000000   0.714286
#                                    Khyber               0.000000   0.125000
#                                    Kurrum               0.000000   0.250000
#                                    Mohmand              0.000000   0.000000
#                                    North Waziristan     0.000000   0.500000
# ...

# %%
a = 'C:\\Users\shariq\OneDrive\Data Analysis Git\Pakistan Corona Analysis\pakistan corona dataset'
# Out:
#   File "<ipython-input-37-f0d1e9cd19fe>", line 1
#     a = 'C:\Users\shariq\OneDrive\Data Analysis Git\Pakistan Corona Analysis\pakistan corona dataset'
#        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pkCovid[['Deaths',"City",'Province','Date','Cases','Recovered']].groupby(['Province','City','Date']).mean()
# Out:
#                                                   Deaths  Cases  Recovered
# Province           City                Date
# Azad Jummu Kashmir Bhambore            4/1/2020      0.0    2.0        0.0
#                    Mirpur              3/18/2020     0.0    1.0        0.0
#                                        3/26/2020     0.0    1.0        0.0
#                                        4/5/2020      0.0    2.0        0.0
#                    Muzaffarabad        3/29/2020     0.0    4.0        0.0
#                                        4/10/2020     0.0    0.0        0.0
#                                        4/11/2020     0.0    1.0        0.0
#                                        4/12/2020     0.0    6.0        1.0
#                                        4/13/2020     0.0    3.0        0.0
#                                        4/15/2020     0.0    3.0        0.0
#                                        4/17/2020     0.0    2.0        0.0
# ...

# %%
pd.options.display.max_columns
pkCovid['Date'].unique()
# Out:
# array(['2/26/2020', '2/29/2020', '3/2/2020', '3/6/2020', '3/7/2020',
#        '3/9/2020', '3/10/2020', '3/11/2020', '3/12/2020', '3/13/2020',
#        '3/15/2020', '3/16/2020', '3/17/2020', '3/18/2020', '3/19/2020',
#        '3/20/2020', '3/21/2020', '3/22/2020', '3/23/2020', '3/24/2020',
#        '3/25/2020', '3/26/2020', '3/27/2020', '3/28/2020', '3/29/2020',
#        '3/30/2020', '3/31/2020', '4/1/2020', '4/2/2020', '4/3/2020',
#        '4/4/2020', '4/5/2020', '4/6/2020', '4/7/2020', '4/8/2020',
#        '4/9/2020', '4/10/2020', '4/11/2020', '4/12/2020', '4/13/2020',
#        '4/14/2020', '4/15/2020', '4/16/2020', '4/17/2020', '4/18/2020',
#        '4/19/2020'], dtype=object)

# %%
pkCovid['Date'].min()
# Out:
# '2/26/2020'

# %%
pkCovid['Date'].max()
# Out:
# '4/9/2020'
